# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinki021/pandas/blob/main/6)PivatTables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    461     82   John  January      Q1
# 1  2023-01-02       B   West    963     27   Mary  January      Q1
# 2  2023-01-03       C  North    165     36    Bob  January      Q1
# 3  2023-01-04       D  South    168     11  Alice  January      Q1
# 4  2023-01-05       A   East    591     43   John  January      Q1
# 5  2023-01-06       B   West    745     86   Mary  January      Q1
# 6  2023-01-07       C  North    993     62    Bob  January      Q1
# 7  2023-01-08       D  South    418     48  Alice  January      Q1
# 8  2023-01-09       A   East    836     97   John  January      Q1
# 9  2023-01-10       B   West    439     45   Mary  January      Q1
# 10 2023-01-11       C  North    683     42    Bob  January      Q1
# 11 2023-01-12       D  South    961     20  Alice  January      Q1
# 12 2023-01-13       A   East    163     37   John  January      Q1
# 13 2023-01-14       B   West    147     55   Mary  January      Q1
# 14 2023-01-15       C  North    309     24    Bob  January      Q1
# 15 2023-01-16       D  South    451     73  Alice  January      Q1
# 16 2023-01-17       A   East    785     91   John  January      Q1
# 17 2023-01-18       B   West    471     91   Mary  January      Q1
# 18 2023-01-19       C  North    743     95    Bob  January      Q1
# 19 2023-01-20       D  South    910     43  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='sum')
# Out:
# Product       A       B       C       D
# Region
# East     2836.0     NaN     NaN     NaN
# North       NaN     NaN  2893.0     NaN
# South       NaN     NaN     NaN  2908.0
# West        NaN  2765.0     NaN     NaN

# %%
pivot2=pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     567.2    NaN    NaN    NaN  70.0   NaN   NaN   NaN
# North      NaN    NaN  578.6    NaN   NaN   NaN  51.8   NaN
# South      NaN    NaN    NaN  581.6   NaN   NaN   NaN  39.0
# West       NaN  553.0    NaN    NaN   NaN  60.8   NaN   NaN

# %% [markdown]
# cross tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
